# %% [markdown]
# <a href="https://colab.research.google.com/github/sagunkayastha/ILab_Tutorials/blob/master/Python_ML_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python for Data Analysis and Visualization

# %%
    import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
df = pd.read_csv('911.csv')

# %%
df.head(3)
# Out:
#          lat        lng  ...                        addr  e
# 0  40.297876 -75.581294  ...      REINDEER CT & DEAD END  1
# 1  40.258061 -75.264680  ...  BRIAR PATH & WHITEMARSH LN  1
# 2  40.121182 -75.351975  ...                    HAWS AVE  1
#
# [3 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 9 columns):
# lat          99492 non-null float64
# lng          99492 non-null float64
# desc         99492 non-null object
# zip          86637 non-null float64
# title        99492 non-null object
# timeStamp    99492 non-null object
# twp          99449 non-null object
# addr         98973 non-null object
# e            99492 non-null int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 6.8+ MB

# %%
df['zip'].value_counts().head(5)
# Out:
# 19401.0    6979
# 19464.0    6643
# 19403.0    4854
# 19446.0    4748
# 19406.0    3174
# Name: zip, dtype: int64

# %% [markdown]
# check 5 values at top of dataframe with head and value_counts

# %% [markdown]
# ### Creating New features

# %%
df.head(10)
# Out:
#          lat        lng  ...                                      addr  e
# 0  40.297876 -75.581294  ...                    REINDEER CT & DEAD END  1
# 1  40.258061 -75.264680  ...                BRIAR PATH & WHITEMARSH LN  1
# 2  40.121182 -75.351975  ...                                  HAWS AVE  1
# 3  40.116153 -75.343513  ...                        AIRY ST & SWEDE ST  1
# 4  40.251492 -75.603350  ...                  CHERRYWOOD CT & DEAD END  1
# 5  40.253473 -75.283245  ...                     CANNON AVE & W 9TH ST  1
# 6  40.182111 -75.127795  ...                  LAUREL AVE & OAKDALE AVE  1
# 7  40.217286 -75.405182  ...              COLLEGEVILLE RD & LYWISKI RD  1
# 8  40.289027 -75.399590  ...             MAIN ST & OLD SUMNEYTOWN PIKE  1
# 9  40.102398 -75.291458  ...  BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD  1
#
# [10 rows x 9 columns]

# %%
value_ = df.loc[1]['title']

# %%
value_.split(':')
# Out:
# ['EMS', ' DIABETIC EMERGENCY']

# %%
value_.split(':')[0]
# Out:
# 'EMS'

# %%
df['Reason'] = df['title'].apply(lambda title: title.split(':')[0])

# %%
df.head()
# Out:
#          lat        lng  ...  e  Reason
# 0  40.297876 -75.581294  ...  1     EMS
# 1  40.258061 -75.264680  ...  1     EMS
# 2  40.121182 -75.351975  ...  1    Fire
# 3  40.116153 -75.343513  ...  1     EMS
# 4  40.251492 -75.603350  ...  1     EMS
#
# [5 rows x 10 columns]

# %%
df['Reason'].value_counts()
# Out:
# EMS        48877
# Traffic    35695
# Fire       14920
# Name: Reason, dtype: int64

# %%
sns.countplot(x='Reason',data=df,palette='viridis')

# %% [markdown]
# ### Splitting Data

# %%
print(df['timeStamp'].iloc[0])
print(type(df['timeStamp'].iloc[0]))
# Out:
# 2015-12-10 17:40:00
# <class 'str'>

# %% [markdown]
# Converting string to datetime

# %%
df['timeStamp'] = pd.to_datetime(df['timeStamp'])
print(type(df['timeStamp'].iloc[0]))
value_ = df['timeStamp'].iloc[0]
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
print(value_)
print(value_.hour)
print(value_.minute)
print(value_.dayofweek)
# Out:
# 2015-12-10 17:40:00
# 17
# 40
# 3

# %%
df['Hour'] = df['timeStamp'].apply(lambda time: time.hour)
df['Month'] = df['timeStamp'].apply(lambda time: time.month)
df['Day of Week'] = df['timeStamp'].apply(lambda time: time.dayofweek)

# %%
df.head()
# Out:
#          lat        lng  ... Month  Day of Week
# 0  40.297876 -75.581294  ...    12            3
# 1  40.258061 -75.264680  ...    12            3
# 2  40.121182 -75.351975  ...    12            3
# 3  40.116153 -75.343513  ...    12            3
# 4  40.251492 -75.603350  ...    12            3
#
# [5 rows x 13 columns]

# %% [markdown]
# Converting Numeric days

# %%
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
df['Day of Week'] = df['Day of Week'].map(dmap)

# %%
df.tail(10)
# Out:
#              lat        lng  ... Month  Day of Week
# 99482  40.340072 -75.591709  ...     8          Wed
# 99483  40.084465 -75.390173  ...     8          Wed
# 99484  40.133037 -75.408463  ...     8          Wed
# 99485  40.143601 -75.427877  ...     8          Wed
# 99486  40.179225 -75.180572  ...     8          Wed
# 99487  40.132869 -75.333515  ...     8          Wed
# 99488  40.006974 -75.289080  ...     8          Wed
# 99489  40.115429 -75.334679  ...     8          Wed
# 99490  40.186431 -75.192555  ...     8          Wed
# 99491  40.207055 -75.317952  ...     8          Wed
#
# [10 rows x 13 columns]

# %%
df['Day of Week'].value_counts()
# Out:
# Tue    15150
# Wed    14879
# Fri    14833
# Mon    14680
# Thu    14478
# Sat    13336
# Sun    12136
# Name: Day of Week, dtype: int64

# %% [markdown]
# ### Reason Plot for days

# %%
sns.countplot(x='Day of Week',data=df,hue='Reason',palette='viridis')

# To relocate the legend
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# ### Reason Plot for month

# %%
sns.countplot(x='Month',data=df,hue='Reason',palette='viridis')

# To relocate the legend
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
byMonth = df.groupby('Month').count()
byMonth
# Out:
#          lat    lng   desc    zip  ...      e  Reason   Hour  Day of Week
# Month                              ...
# 1      13205  13205  13205  11527  ...  13205   13205  13205        13205
# 2      11467  11467  11467   9930  ...  11467   11467  11467        11467
# 3      11101  11101  11101   9755  ...  11101   11101  11101        11101
# 4      11326  11326  11326   9895  ...  11326   11326  11326        11326
# 5      11423  11423  11423   9946  ...  11423   11423  11423        11423
# 6      11786  11786  11786  10212  ...  11786   11786  11786        11786
# 7      12137  12137  12137  10633  ...  12137   12137  12137        12137
# 8       9078   9078   9078   7832  ...   9078    9078   9078         9078
# 12      7969   7969   7969   6907  ...   7969    7969   7969         7969
#
# [9 rows x 12 columns]

# %%
byMonth['Reason'].plot()

# %%
df['Date']=df['timeStamp'].apply(lambda t: t.date())
df
# Out:
#              lat        lng  ... Day of Week        Date
# 0      40.297876 -75.581294  ...         Thu  2015-12-10
# 1      40.258061 -75.264680  ...         Thu  2015-12-10
# 2      40.121182 -75.351975  ...         Thu  2015-12-10
# 3      40.116153 -75.343513  ...         Thu  2015-12-10
# 4      40.251492 -75.603350  ...         Thu  2015-12-10
# ...          ...        ...  ...         ...         ...
# 99487  40.132869 -75.333515  ...         Wed  2016-08-24
# 99488  40.006974 -75.289080  ...         Wed  2016-08-24
# 99489  40.115429 -75.334679  ...         Wed  2016-08-24
# 99490  40.186431 -75.192555  ...         Wed  2016-08-24
# 99491  40.207055 -75.317952  ...         Wed  2016-08-24
#
# [99492 rows x 14 columns]

# %% [markdown]
#  aggregate plot of counts of 911 calls

# %%
df.groupby('Date').count()['twp']
df.groupby('Date').count()['twp'].plot()
plt.tight_layout()

# %%
df[df['Reason']=='Traffic'].groupby('Date').count()['twp'].plot()
plt.title('Traffic')
plt.tight_layout()

# %% [markdown]
# Apply similar function for other reasons

# %%
dayHour = df.groupby(by=['Day of Week','Hour']).count()['Reason'].unstack()
dayHour.head()
# Out:
# Hour          0    1    2    3    4    5   ...   18   19   20   21   22   23
# Day of Week                                ...
# Fri          275  235  191  175  201  194  ...  820  696  667  559  514  474
# Mon          282  221  201  194  204  267  ...  885  746  613  497  472  325
# Sat          375  301  263  260  224  231  ...  778  696  628  572  506  467
# Sun          383  306  286  268  242  240  ...  670  655  537  461  415  330
# Thu          278  202  233  159  182  203  ...  810  698  617  553  424  354
#
# [5 rows x 24 columns]

# %%
plt.figure(figsize=(12,6))
sns.heatmap(dayHour,cmap='viridis')

# %%
dayMonth = df.groupby(by=['Day of Week','Month']).count()['Reason'].unstack()
dayMonth.head()
# Out:
# Month          1     2     3     4     5     6     7     8     12
# Day of Week
# Fri          1970  1581  1525  1958  1730  1649  2045  1310  1065
# Mon          1727  1964  1535  1598  1779  1617  1692  1511  1257
# Sat          2291  1441  1266  1734  1444  1388  1695  1099   978
# Sun          1960  1229  1102  1488  1424  1333  1672  1021   907
# Thu          1584  1596  1900  1601  1590  2065  1646  1230  1266

# %%
plt.figure(figsize=(12,6))
sns.heatmap(dayMonth,cmap='viridis')

# %% [markdown]
# # Part 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Daily Time Spent on Site': consumer time on site in minutes
# 'Age': cutomer age in years
# 'Area Income': Avg. Income of geographical area of consumer
# 'Daily Internet Usage': Avg. minutes a day consumer is on the internet
# 'Ad Topic Line': Headline of the advertisement
# 'City': City of consumer
# 'Male': Whether or not consumer was male
# 'Country': Country of consumer
# 'Timestamp': Time at which consumer clicked on Ad or closed window
# 'Clicked on Ad': 0 or 1 indicated clicking on Ad

# %%
ad_data = pd.read_csv('advertising.csv')

# %%
ad_data.head()
# Out:
#    Daily Time Spent on Site  Age  ...            Timestamp  Clicked on Ad
# 0                     68.95   35  ...  2016-03-27 00:53:11              0
# 1                     80.23   31  ...  2016-04-04 01:39:02              0
# 2                     69.47   26  ...  2016-03-13 20:35:42              0
# 3                     74.15   29  ...  2016-01-10 02:31:19              0
# 4                     68.37   35  ...  2016-06-03 03:36:18              0
#
# [5 rows x 10 columns]

# %%
ad_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
# Daily Time Spent on Site    1000 non-null float64
# Age                         1000 non-null int64
# Area Income                 1000 non-null float64
# Daily Internet Usage        1000 non-null float64
# Ad Topic Line               1000 non-null object
# City                        1000 non-null object
# Male                        1000 non-null int64
# Country                     1000 non-null object
# Timestamp                   1000 non-null object
# Clicked on Ad               1000 non-null int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
ad_data.describe()
# Out:
#        Daily Time Spent on Site          Age  ...         Male  Clicked on Ad
# count               1000.000000  1000.000000  ...  1000.000000     1000.00000
# mean                  65.000200    36.009000  ...     0.481000        0.50000
# std                   15.853615     8.785562  ...     0.499889        0.50025
# min                   32.600000    19.000000  ...     0.000000        0.00000
# 25%                   51.360000    29.000000  ...     0.000000        0.00000
# 50%                   68.215000    35.000000  ...     0.000000        0.50000
# 75%                   78.547500    42.000000  ...     1.000000        1.00000
# max                   91.430000    61.000000  ...     1.000000        1.00000
#
# [8 rows x 6 columns]

# %%
sns.set_style('whitegrid')
ad_data['Age'].hist(bins=30)
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
sns.jointplot(x='Age',y='Daily Time Spent on Site',data=ad_data,color='red',kind='kde');

# %%
sns.jointplot(x='Daily Time Spent on Site',y='Daily Internet Usage',data=ad_data,color='green')

# %%
sns.pairplot(ad_data,hue='Clicked on Ad',palette='bwr')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# # Machine Learning

# %%
from sklearn.model_selection import train_test_split

# %%
X = ad_data[['Daily Time Spent on Site', 'Age', 'Area Income','Daily Internet Usage', 'Male']]
y = ad_data['Clicked on Ad']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# # Test

# %%
X_test[0:2]
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male
# 521                     63.26   29     54787.37                120.46     1
# 737                     71.23   52     41521.28                122.59     0

# %%
predictions = logmodel.predict(X_test[0:2])

# %%
predictions
# Out:
# array([1, 1])

# %%
np.array(y_test[0:2])
# Out:
# array([1, 1])

# %% [markdown]
# # **Convolution Example**

# %%
import pandas as pd
import numpy as np
import os
import keras
import matplotlib.pyplot as plt
from keras.layers import Dense,GlobalAveragePooling2D
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.models import Model
from keras.optimizers import Adam

# %%
model = VGG16()
# Out:
# ...
# 553467904/553467096 [==============================] - 38s 0us/step

# %%
# !wget -O panda.jpg https://kids.nationalgeographic.com/content/dam/kids/photos/animals/Mammals/A-G/giant-panda-eating.ngsversion.1411231575277.adapt.1900.1.jpg panda.jpg
# Out:
# --2019-12-12 18:25:00--  https://kids.nationalgeographic.com/content/dam/kids/photos/animals/Mammals/A-G/giant-panda-eating.ngsversion.1411231575277.adapt.1900.1.jpg
# Resolving kids.nationalgeographic.com (kids.nationalgeographic.com)... 104.93.0.112
# Connecting to kids.nationalgeographic.com (kids.nationalgeographic.com)|104.93.0.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 227669 (222K) [image/jpeg]
# Saving to: ‘panda.jpg’
#
# panda.jpg           100%[===================>] 222.33K   505KB/s    in 0.4s
#
# 2019-12-12 18:25:01 (505 KB/s) - ‘panda.jpg’ saved [227669/227669]
#
# --2019-12-12 18:25:01--  http://panda.jpg/
# Resolving panda.jpg (panda.jpg)... failed: Name or service not known.
# wget: unable to resolve host address ‘panda.jpg’
# FINISHED --2019-12-12 18:25:01--
# Total wall clock time: 1.1s
# Downloaded: 1 files, 222K in 0.4s (505 KB/s)

# %%
img=load_img('panda.jpg',target_size=(224, 224))
image = img_to_array(img)
plt.imshow(img)

# %%
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
image[0:10,0,0]
# Out:
# array([[107., 103., 102.]], dtype=float32)

# %%
# preprocess
image = preprocess_input(image)
image[0:10,0,0]
# Out:
# array([[ -1.939003, -13.778999, -16.68    ]], dtype=float32)

# %%
pred = model.predict(image)
label = decode_predictions(pred)
label
# Out:
# ...
# 40960/35363 [==================================] - 0s 0us/step
# [[('n02510455', 'giant_panda', 0.9993993),
#   ('n02133161', 'American_black_bear', 0.00024792211),
#   ('n02134418', 'sloth_bear', 9.755436e-05),
#   ('n02483362', 'gibbon', 7.892587e-05),
#   ('n02488702', 'colobus', 4.616873e-05)]]
